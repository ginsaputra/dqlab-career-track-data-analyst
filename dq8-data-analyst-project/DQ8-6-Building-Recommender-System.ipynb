# %% [markdown]
# # Building Recommender System

# %% [markdown]
# In a very general way, recommender systems are algorithms aimed at suggesting relevant items to users (items being movies to watch, text to read, products to buy or anything else depending on industries). During the last few decades, with the rise of Youtube, Amazon, Netflix and many other such web services, recommender systems have taken more and more place in our lives. From e-commerce (suggest to buyers articles that could interest them) to online advertisement (suggest to users the right contents, matching their preferences), recommender systems are today unavoidable in our daily online journeys.[<sup>[ref]</sup>](https://towardsdatascience.com/introduction-to-recommender-systems-6c66cf15ada)

# %% [markdown]
# ## Load Datasets

# %% [markdown]
# Import the required Python libraries and load the datasets as pandas dataframes.

# %%
import pandas as pd
import numpy as np

# %%
file_movie = 'https://storage.googleapis.com/dqlab-dataset/title.basics.tsv'
file_rating = 'https://storage.googleapis.com/dqlab-dataset/title.ratings.tsv'

movie_df = pd.read_csv(file_movie, sep='\t')
rating_df = pd.read_csv(file_rating, sep='\t')

# %% [markdown]
# ## Data Cleaning: `movie_df`

# %% [markdown]
# Preview the first few rows of the dataframe, check the shape and data types.

# %%
movie_df.head()
# Out:
#       tconst  titleType                                      primaryTitle  \
# 0  tt0221078      short                         Circle Dance, Ute Indians
# 1  tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2  tt7157720  tvEpisode                                     Episode #3.41
# 3  tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4  tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
#
#                                       originalTitle  isAdult startYear  \
# 0                         Circle Dance, Ute Indians        0      1898
# 1  ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                     Episode #3.41        0      2016
# 3                         Episode dated 16 May 1987        0      1987
# 4                  Frances Bavier: Aunt Bee Retires        0      1973
#
#   endYear runtimeMinutes             genres
# 0      \N             \N  Documentary,Short
# 1      \N             \N       Comedy,Drama
# 2      \N             29   Comedy,Game-Show
# 3      \N             \N               News
# 4      \N             \N        Documentary

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9025 entries, 0 to 9024
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          9025 non-null   object
#  1   titleType       9025 non-null   object
#  2   primaryTitle    9011 non-null   object
#  3   originalTitle   9011 non-null   object
#  4   isAdult         9025 non-null   int64
#  5   startYear       9025 non-null   object
#  6   endYear         9025 non-null   object
#  7   runtimeMinutes  9025 non-null   object
#  8   genres          9014 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 634.7+ KB

# %% [markdown]
# The dataset consists 9025 entries, with the columns `primaryTitle`, `originalTitle`, and `genres` having missing missing values. Using the method `.isnull()`, we check the number of missing values.

# %%
movie_df.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      14
# originalTitle     14
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            11
# dtype: int64

# %% [markdown]
# Slice the dataset to display entries containing missing values.

# %%
movie_df.loc[(
    movie_df['primaryTitle'].isnull()) | (
    movie_df['originalTitle'].isnull()) | (
    movie_df['genres'].isnull()
)]
# Out:
#           tconst  titleType  \
# 9000  tt10790040  tvEpisode
# 9001  tt10891902  tvEpisode
# 9002  tt11737860  tvEpisode
# 9003  tt11737862  tvEpisode
# 9004  tt11737866  tvEpisode
# 9005  tt11737872  tvEpisode
# 9006  tt11737874  tvEpisode
# 9007   tt1971246  tvEpisode
# 9008   tt2067043  tvEpisode
# 9009   tt4404732  tvEpisode
# 9010   tt5773048  tvEpisode
# 9011   tt8473688  tvEpisode
# 9012   tt8541336  tvEpisode
# 9013   tt9824302  tvEpisode
# 9014  tt10233364  tvEpisode
# 9015  tt10925142  tvEpisode
# 9016  tt10970874  tvEpisode
# 9017  tt11670006  tvEpisode
# 9018  tt11868642  tvEpisode
# 9019   tt2347742  tvEpisode
# 9020   tt3984412  tvEpisode
# 9021   tt8740950  tvEpisode
# 9022   tt9822816  tvEpisode
# 9023   tt9900062  tvEpisode
# 9024   tt9909210  tvEpisode
#
#                                            primaryTitle originalTitle  \
# 9000                                                NaN           NaN
# 9001                                                NaN           NaN
# 9002                                                NaN           NaN
# 9003                                                NaN           NaN
# 9004                                                NaN           NaN
# 9005                                                NaN           NaN
# 9006                                                NaN           NaN
# 9007                                                NaN           NaN
# 9008                                                NaN           NaN
# 9009                                                NaN           NaN
# 9010                                                NaN           NaN
# 9011                                                NaN           NaN
# 9012                                                NaN           NaN
# 9013                                                NaN           NaN
# 9014  Rolling in the Deep Dish\tRolling in the Deep ...             0
# 9015  The IMDb Show on Location: Star Wars Galaxy's ...             0
# 9016  Die Bauhaus-Stadt Tel Aviv - Vorbild für die M...             0
# 9017  ...ein angenehmer Unbequemer...\t...ein angene...             0
# 9018  GGN Heavyweight Championship Lungs With Mike T...             0
# 9019  No sufras por la alergia esta primavera\tNo su...             0
# 9020  I'm Not Going to Come Last, I'm Just Going to ...             0
# 9021  Weight Loss Resolution Restart - Ins & Outs of...             0
# 9022  Zwischen Vertuschung und Aufklärung - Missbrau...             0
# 9023  The Direction of Yuu's Love: Hings Aren't Goin...             0
# 9024  Politik und/oder Moral - Wie weit geht das Ver...             0
#
#       isAdult startYear endYear          runtimeMinutes                genres
# 9000        0      2019      \N                      \N                    \N
# 9001        0      2020      \N                      \N                 Crime
# 9002        0      2020      \N                      \N  Comedy,Drama,Romance
# 9003        0      2020      \N                      \N  Comedy,Drama,Romance
# 9004        0      2020      \N                      \N  Comedy,Drama,Romance
# 9005        0      2020      \N                      \N                    \N
# 9006        0      2020      \N                      \N  Comedy,Drama,Romance
# 9007        0      2011      \N                      \N             Biography
# 9008        0      1965      \N                      \N                 Music
# 9009        0      2015      \N                      \N                Comedy
# 9010        0      2015      \N                      \N             Talk-Show
# 9011        0      1987      \N                      \N                 Drama
# 9012        0      2018      \N                      \N    Reality-TV,Romance
# 9013        0      2016      \N                      \N           Documentary
# 9014     2019        \N      \N              Reality-TV                   NaN
# 9015     2019        \N      \N               Talk-Show                   NaN
# 9016     2019        \N      \N                      \N                   NaN
# 9017     1981        \N      \N             Documentary                   NaN
# 9018     2020        \N      \N               Talk-Show                   NaN
# 9019     2004        \N      \N                      \N                   NaN
# 9020     2014        \N      \N              Reality-TV                   NaN
# 9021     2015        \N      \N              Reality-TV                   NaN
# 9022     2019        \N      \N                      \N                   NaN
# 9023     1994        \N      \N  Animation,Comedy,Drama                   NaN
# 9024     2005        \N      \N                      \N                   NaN

# %% [markdown]
# Update the dataframe `movie_df` by excluding the missing values. Re-check the number of entries after the update.

# %%
movie_df = movie_df.loc[(
    movie_df['primaryTitle'].notnull()) & (
    movie_df['originalTitle'].notnull()) & (
    movie_df['genres'].notnull()
)]

len(movie_df)
# Out:
# 9000

# %% [markdown]
# Notice that the columns `startYear`, `endYear`, and `runtimeMinutes` contains entries `'\\N'`. This value will be replaced with `'NaN'` and the columns will be typecasted to `'float64'` accordingly (they cannot be typecasted to `'int64'` because of the presence of NaNs).

# %%
movie_df['startYear'] = movie_df['startYear'].replace(
    '\\N', np.nan).astype('float64')
movie_df['endYear'] = movie_df['endYear'].replace(
    '\\N', np.nan).astype('float64')
movie_df['runtimeMinutes'] = movie_df['runtimeMinutes'].replace(
    '\\N', np.nan).astype('float64')

print(movie_df['startYear'].unique()[:5],
      movie_df['endYear'].unique()[:5],
      movie_df['runtimeMinutes'].unique()[:5],
      sep='\n')
# Out:
# [1898. 2018. 2016. 1987. 1973.]
# [  nan 2005. 1955. 2006. 1999.]
# [nan 29.  7. 23. 85.]

# %% [markdown]
# Create a function to transform each entry in the column `genres` into a list. An empty list will be returned if no genres are available.

# %%
def transform_to_list(entry):
    if ',' in entry:
        return entry.split(',')
    else:
        return []

movie_df['genres'] = movie_df['genres'].apply(lambda x: transform_to_list(x))
movie_df.head()
# Out:
#       tconst  titleType                                      primaryTitle  \
# 0  tt0221078      short                         Circle Dance, Ute Indians
# 1  tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2  tt7157720  tvEpisode                                     Episode #3.41
# 3  tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4  tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
#
#                                       originalTitle  isAdult  startYear  \
# 0                         Circle Dance, Ute Indians        0     1898.0
# 1  ¡El #TeamOsos va con todo al "Reality del amor"!        0     2018.0
# 2                                     Episode #3.41        0     2016.0
# 3                         Episode dated 16 May 1987        0     1987.0
# 4                  Frances Bavier: Aunt Bee Retires        0     1973.0
#
#    endYear  runtimeMinutes                genres
# 0      NaN             NaN  [Documentary, Short]
# 1      NaN             NaN       [Comedy, Drama]
# 2      NaN            29.0   [Comedy, Game-Show]
# 3      NaN             NaN                    []
# 4      NaN             NaN                    []

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          9000 non-null   object
#  1   titleType       9000 non-null   object
#  2   primaryTitle    9000 non-null   object
#  3   originalTitle   9000 non-null   object
#  4   isAdult         9000 non-null   int64
#  5   startYear       8338 non-null   float64
#  6   endYear         79 non-null     float64
#  7   runtimeMinutes  2594 non-null   float64
#  8   genres          9000 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 703.1+ KB

# %% [markdown]
# ## Data Cleaning: `rating_df`

# %% [markdown]
# Preview the the first few rows, check the dataframe information.

# %%
rating_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1608
# 1  tt0000002            6.0       197
# 2  tt0000003            6.5      1285
# 3  tt0000004            6.1       121
# 4  tt0000005            6.1      2050

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030009 entries, 0 to 1030008
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1030009 non-null  object
#  1   averageRating  1030009 non-null  float64
#  2   numVotes       1030009 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.6+ MB

# %% [markdown]
# This dataframe contains more than one million entries, significantly larger than `movie_df`.

# %% [markdown]
# ## Merge Dataframes

# %% [markdown]
# The dataframes `movie_df` and `rating_df` are merged, with the parameter `how='inner'`. The joining is done on the column `'tconst'` which exists in both dataframes. The result will be an intersection of the two dataframes.

# %%
movie_rating_df = pd.merge(movie_df, rating_df, on='tconst', how='inner')
movie_rating_df.head()
# Out:
#       tconst  titleType              primaryTitle             originalTitle  \
# 0  tt0043745      short                 Lion Down                 Lion Down
# 1  tt0167491      video         Wicked Covergirls         Wicked Covergirls
# 2  tt6574096  tvEpisode      Shadow Play - Part 2      Shadow Play - Part 2
# 3  tt6941700  tvEpisode              RuPaul Roast              RuPaul Roast
# 4  tt7305674      video  UCLA Track & Field Promo  UCLA Track & Field Promo
#
#    isAdult  startYear  endYear  runtimeMinutes  \
# 0        0     1951.0      NaN             7.0
# 1        1     1998.0      NaN            85.0
# 2        0     2017.0      NaN            22.0
# 3        0     2017.0      NaN             NaN
# 4        0     2017.0      NaN             NaN
#
#                            genres  averageRating  numVotes
# 0     [Animation, Comedy, Family]            7.1       459
# 1                              []            5.7         7
# 2  [Adventure, Animation, Comedy]            8.5       240
# 3                              []            8.0        11
# 4                  [Short, Sport]            9.7         7

# %%
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1376 entries, 0 to 1375
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1376 non-null   object
#  1   titleType       1376 non-null   object
#  2   primaryTitle    1376 non-null   object
#  3   originalTitle   1376 non-null   object
#  4   isAdult         1376 non-null   int64
#  5   startYear       1376 non-null   float64
#  6   endYear         26 non-null     float64
#  7   runtimeMinutes  1004 non-null   float64
#  8   genres          1376 non-null   object
#  9   averageRating   1376 non-null   float64
#  10  numVotes        1376 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 129.0+ KB

# %% [markdown]
# Drop missing values from the columns `'startYear'` and `'runtimeMinutes'`

# %%
movie_rating_df = movie_rating_df.dropna(
    subset=['startYear', 'runtimeMinutes'])
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1004 entries, 0 to 1374
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1004 non-null   object
#  1   titleType       1004 non-null   object
#  2   primaryTitle    1004 non-null   object
#  3   originalTitle   1004 non-null   object
#  4   isAdult         1004 non-null   int64
#  5   startYear       1004 non-null   float64
#  6   endYear         17 non-null     float64
#  7   runtimeMinutes  1004 non-null   float64
#  8   genres          1004 non-null   object
#  9   averageRating   1004 non-null   float64
#  10  numVotes        1004 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 94.1+ KB

# %% [markdown]
# ## Building Simple Recommender System

# %% [markdown]
# A simple recommender system is based solely on ranking, i.e., the movies will be sorted by some popularity metrics such as the number of votes, ratings, etc. In this case, the metric that will be used is 'weighted average rating', which takes into account the average rating and number of votes.
#
# $weighted\;rating = \frac{Rv+Cm}{v+m}$
#
#     R = average rating
#     C = average rating of all movies
#     v = number of votes
#     m = minimum votes for top-scoring movies

# %%
C = movie_rating_df['averageRating'].mean()
m = movie_rating_df['numVotes'].quantile(0.8)
print(f'C = {C:.2f}',
      f'm = {m:.2f}', sep='\n')
# Out:
# C = 6.83
# m = 229.00

# %% [markdown]
# Define a function that returns a new column `score`, which contains values of the weighted average rating.

# %%
def imdb_weighted_rating(df, var=0.8):
    v = df['numVotes']
    R = df['averageRating']
    C = df['averageRating'].mean()
    m = df['numVotes'].quantile(var)
    df['score'] = (R*v + C*m) / (m + v) #Rumus IMDb 
    return df['score']

# %%
imdb_weighted_rating(movie_rating_df)
movie_rating_df.head()
# Out:
#       tconst  titleType          primaryTitle         originalTitle  isAdult  \
# 0  tt0043745      short             Lion Down             Lion Down        0
# 1  tt0167491      video     Wicked Covergirls     Wicked Covergirls        1
# 2  tt6574096  tvEpisode  Shadow Play - Part 2  Shadow Play - Part 2        0
# 5  tt2262289      movie               The Pin               The Pin        0
# 6  tt0874027  tvEpisode         Episode #32.9         Episode #32.9        0
#
#    startYear  endYear  runtimeMinutes                          genres  \
# 0     1951.0      NaN             7.0     [Animation, Comedy, Family]
# 1     1998.0      NaN            85.0                              []
# 2     2017.0      NaN            22.0  [Adventure, Animation, Comedy]
# 5     2013.0      NaN            85.0                              []
# 6     2006.0      NaN            29.0       [Comedy, Game-Show, News]
#
#    averageRating  numVotes     score
# 0            7.1       459  7.009992
# 1            5.7         7  6.796077
# 2            8.5       240  7.684380
# 5            7.7        27  6.921384
# 6            8.0         8  6.869089

# %% [markdown]
# Create a function that recommends movies based simply on their scores.

# %%
def simple_recommender(df, top=100):
    # On default, return 100 top-scored titles
    df = df.loc[df['numVotes'] >= m]
    df = df.sort_values(by='score', ascending=False)
    df = df[:top]
    return df

# %% [markdown]
# Get a recommendation of 25 top-scoring movies:

# %%
simple_recommender(movie_rating_df, top=25)
# Out:
#          tconst  titleType                                   primaryTitle  \
# 68    tt4110822  tvEpisode                                  S.O.S. Part 2
# 236   tt2200252      video                    Attack of the Clones Review
# 1181  tt7697962  tvEpisode            Chapter Seventeen: The Missionaries
# 326   tt7124590  tvEpisode            Chapter Thirty-Four: Judgment Night
# 1045  tt0533506  tvEpisode                                       The Prom
# 71    tt8399426  tvEpisode                                        Savages
# 1234  tt2843830  tvEpisode                                          VIII.
# 1087  tt4295140   tvSeries                                   Chef's Table
# 1054  tt2503932  tvEpisode                                Trial and Error
# 448   tt0337566      video                       AC/DC: Live at Donington
# 624   tt0620159  tvEpisode                                     Strike Out
# 1281  tt3166390  tvEpisode                         Looking for a Plus-One
# 314   tt0954759  tvEpisode                                   Ben Franklin
# 189   tt5661506      video            Florence + the Machine: The Odyssey
# 151   tt3954426  tvEpisode                                Bleeding Kansas
# 1344  tt6644294  tvEpisode                 The Hostile Hospital: Part Two
# 1242  tt3677742  tvSpecial  Saturday Night Live: 40th Anniversary Special
# 1217  tt3642464  tvEpisode                                    Giant Woman
# 544   tt0734655  tvEpisode                              The Little People
# 49    tt9119838  tvEpisode                      Parisian Legend Has It...
# 357   tt4084774  tvEpisode                           Trial and Punishment
# 1111  tt4174072  tvEpisode                     Immortal Emerges from Cave
# 790   tt4279086  tvEpisode                       And Santa's Midnight Run
# 972   tt0048028      movie                                   East of Eden
# 819   tt0032156      movie            The Story of the Last Chrysanthemum
#
#                                       originalTitle  isAdult  startYear  \
# 68                                    S.O.S. Part 2        0     2015.0
# 236                     Attack of the Clones Review        0     2010.0
# 1181            Chapter Seventeen: The Missionaries        0     2019.0
# 326             Chapter Thirty-Four: Judgment Night        0     2018.0
# 1045                                       The Prom        0     1999.0
# 71                                          Savages        0     2018.0
# 1234                                          VIII.        0     2014.0
# 1087                                   Chef's Table        0     2015.0
# 1054                                Trial and Error        0     2013.0
# 448                        AC/DC: Live at Donington        0     1992.0
# 624                                      Strike Out        0     2000.0
# 1281                         Looking for a Plus-One        0     2014.0
# 314                                    Ben Franklin        0     2007.0
# 189             Florence + the Machine: The Odyssey        0     2016.0
# 151                                 Bleeding Kansas        0     2014.0
# 1344                 The Hostile Hospital: Part Two        0     2018.0
# 1242  Saturday Night Live: 40th Anniversary Special        0     2015.0
# 1217                                    Giant Woman        0     2014.0
# 544                               The Little People        0     1962.0
# 49                        Parisian Legend Has It...        0     2019.0
# 357                            Trial and Punishment        0     2015.0
# 1111                     Immortal Emerges from Cave        0     2017.0
# 790                        And Santa's Midnight Run        0     2014.0
# 972                                    East of Eden        0     1955.0
# 819                              Zangiku monogatari        0     1939.0
#
#       endYear  runtimeMinutes                          genres  averageRating  \
# 68        NaN            43.0      [Action, Adventure, Drama]            9.4
# 236       NaN            86.0                              []            9.3
# 1181      NaN            54.0        [Drama, Fantasy, Horror]            9.2
# 326       NaN            42.0         [Crime, Drama, Mystery]            9.1
# 1045      NaN            60.0        [Action, Drama, Fantasy]            8.9
# 71        NaN            58.0       [Drama, Fantasy, Romance]            9.0
# 1234      NaN            57.0              [Adventure, Drama]            8.9
# 1087      NaN            50.0                              []            8.6
# 1054      NaN            43.0        [Drama, Fantasy, Horror]            8.6
# 448       NaN           120.0            [Documentary, Music]            8.5
# 624       NaN            30.0                              []            8.7
# 1281      NaN            28.0        [Comedy, Drama, Romance]            8.7
# 314       NaN            21.0                              []            8.1
# 189       NaN            49.0                              []            8.8
# 151       NaN            42.0                [Drama, Western]            8.6
# 1344      NaN            40.0      [Adventure, Comedy, Drama]            8.3
# 1242      NaN           106.0                              []            8.1
# 1217      NaN            11.0  [Adventure, Animation, Comedy]            8.4
# 544       NaN            25.0        [Drama, Fantasy, Horror]            8.1
# 49        NaN            42.0                              []            8.9
# 357       NaN            56.0              [Adventure, Drama]            8.8
# 1111      NaN            53.0      [Action, Adventure, Crime]            8.0
# 790       NaN            42.0     [Action, Adventure, Comedy]            8.2
# 972       NaN           118.0                              []            7.9
# 819       NaN           143.0                [Drama, Romance]            7.9
#
#       numVotes     score
# 68        3820  9.254624
# 236       1411  8.955045
# 1181      1536  8.892450
# 326       1859  8.850993
# 1045      2740  8.740308
# 71        1428  8.700045
# 1234      1753  8.660784
# 1087     12056  8.566998
# 1054      2495  8.451165
# 448       1343  8.256663
# 624        401  8.020118
# 1281       396  8.014679
# 314       2766  8.002863
# 189        330  7.992798
# 151        437  7.991253
# 1344       812  7.976536
# 1242      1931  7.965312
# 1217       566  7.947641
# 544       1559  7.937290
# 49         263  7.936330
# 357        289  7.928908
# 1111      2898  7.914287
# 790        823  7.901687
# 972      38543  7.893678
# 819       2974  7.823470

# %% [markdown]
# Improve recommender with user preference by adding specific filters: `isAdult`, `startYear`, `genre`.

# %%
def user_prefer_recommender(
    df, ask_adult, ask_start_year, ask_genre, top=100):
    
    # ask_adult = yes/no
    if ask_adult.lower() == 'yes':
        df = df.loc[df['isAdult'] == 1]
    elif ask_adult.lower() == 'no':
        df = df.loc[df['isAdult'] == 0]

    # ask_start_year = numeric
    df = df.loc[df['startYear'] >= int(ask_start_year)]

    # ask_genre = 'all' or specified
    if ask_genre.lower() == 'all':
        df = df
    else:
        def filter_genre(genre):
            if ask_genre.lower() in str(genre).lower():
                return True
            else:
                return False
        df = df.loc[df['genres'].apply(lambda x: filter_genre(x))]

    df = df.loc[df['numVotes'] >= m]
    df = df.sort_values(by='score', ascending=False)
    df = df[:top]
    return df

# %%
df = movie_rating_df.copy()

user_prefer_recommender(
    df,
    ask_adult = 'No',
    ask_start_year = 2000,
    ask_genre = 'Romance',
    top=25)
# Out:
#          tconst  titleType               primaryTitle  \
# 71    tt8399426  tvEpisode                    Savages
# 1281  tt3166390  tvEpisode     Looking for a Plus-One
# 455   tt1115217  tvEpisode        We're Not from Here
# 961   tt6077690  tvEpisode  The Hot Tub Contamination
# 1090  tt0212815      movie                   Big Eden
# 691   tt3663996  tvEpisode                Storm Watch
# 164   tt0464049      movie           The History Boys
# 927   tt3663990  tvEpisode                      Pilot
# 585   tt5051278    tvMovie  A Midsummer Night's Dream
# 1126  tt2151739      movie      Meet Me in Montenegro
# 637   tt0857275      movie            Wonderful World
# 713   tt0363741      movie      Kilichundan Mampazham
# 127   tt5680744      movie                 Permitidos
# 55    tt0446043      movie             Opie Gets Laid
# 690   tt4477536      movie         Fifty Shades Freed
# 1039  tt5227468      movie              Beiimaan Love
#
#                   originalTitle  isAdult  startYear  endYear  runtimeMinutes  \
# 71                      Savages        0     2018.0      NaN            58.0
# 1281     Looking for a Plus-One        0     2014.0      NaN            28.0
# 455         We're Not from Here        0     2007.0      NaN            22.0
# 961   The Hot Tub Contamination        0     2016.0      NaN            20.0
# 1090                   Big Eden        0     2000.0      NaN           118.0
# 691                 Storm Watch        0     2014.0      NaN            43.0
# 164            The History Boys        0     2006.0      NaN           109.0
# 927                       Pilot        0     2014.0      NaN            44.0
# 585   A Midsummer Night's Dream        0     2016.0      NaN            90.0
# 1126      Meet Me in Montenegro        0     2014.0      NaN            90.0
# 637             Wonderful World        0     2009.0      NaN            89.0
# 713       Kilichundan Mampazham        0     2003.0      NaN           154.0
# 127                  Permitidos        0     2016.0      NaN           106.0
# 55                    Sunnyvale        0     2005.0      NaN            75.0
# 690          Fifty Shades Freed        0     2018.0      NaN           105.0
# 1039              Beiimaan Love        0     2016.0      NaN           120.0
#
#                           genres  averageRating  numVotes     score
# 71     [Drama, Fantasy, Romance]            9.0      1428  8.700045
# 1281    [Comedy, Drama, Romance]            8.7       396  8.014679
# 455            [Comedy, Romance]            7.7      2480  7.626421
# 961            [Comedy, Romance]            7.5      1819  7.425036
# 1090    [Comedy, Drama, Romance]            7.3      3906  7.273948
# 691             [Drama, Romance]            7.0       309  6.927461
# 164     [Comedy, Drama, Romance]            6.8     19858  6.800337
# 927             [Drama, Romance]            6.6       403  6.683187
# 585   [Comedy, Fantasy, Romance]            6.3       599  6.446466
# 1126    [Comedy, Drama, Romance]            5.8       258  6.284136
# 637             [Drama, Romance]            6.1      2288  6.166378
# 713            [Comedy, Romance]            5.7       404  6.108648
# 127            [Comedy, Romance]            5.6       765  5.883274
# 55             [Comedy, Romance]            4.7       230  5.762471
# 690   [Drama, Romance, Thriller]            4.5     50572  4.510501
# 1039  [Drama, Romance, Thriller]            2.8       374  4.330305
